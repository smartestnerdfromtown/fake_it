# %%
import pandas as pd
from name import (
    generate_name,
    generate_surname,
    generate_fullname
)
from mail import generate_email

# %%
names = [generate_name() for _ in range(10)]
surnames = [generate_surname() for _ in range(10)]
emails = [generate_email(names[i], surnames[i], random_domain=True) for i in range(10)]



df = pd.DataFrame({
    "name": names,
    "surname": surnames,
    "email": emails
})

# %%
df
# Out:
#       name    surname                          email
# 0   Sergey    Zaitsev       sergey_zaitsev@gmail.com
# 1    Roman    Sokolov            roman_sokolov@bk.ru
# 2     Ivan    Sokolov         ivan_sokolov@gmail.com
# 3     Ivan  Mikhailov        ivan_mikhailov@inbox.ru
# 4  Nikolay    Fedorov      nikolay_fedorov@gmail.com
# 5     Ivan    Morozov       ivan_morozov@hotmail.com
# 6    Pavel     Petrov      pavel_petrov@tutanota.com
# 7   Andrey     Karpov           andrey_karpov@gmx.de
# 8  Nikolay  Kuznetsov  nikolay_kuznetsov@hotmail.com
# 9    Pavel     Kozlov          pavel_kozlov@mail.com
